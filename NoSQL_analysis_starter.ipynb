# %% [markdown]
# # Eat Safe, Love

# %% [markdown]
# ## Notebook Set Up

# %%
from pymongo import MongoClient
import pandas as pd
from pprint import pprint

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
# assign the uk_food database to a variable name
db = mongo['uk_food']

# %%
# review the collections in our database
print(db.list_collection_names())
# Out:
# ['establishments']

# %%
# assign the collection to a variable
establishments = db['establishments']

# %% [markdown]
# ## Part 3: Exploratory Analysis
# Unless otherwise stated, for each question:
# * Use `count_documents` to display the number of documents contained in the result.
# * Display the first document in the results using `pprint`.
# * Convert the result to a Pandas DataFrame, print the number of rows in the DataFrame, and display the first 10 rows.

# %% [markdown]
# ### 1. Which establishments have a hygiene score equal to 20?

# %%
# Find the establishments with a hygiene score of 20
query  = {"scores.Hygiene": 20}

# Use count_documents to display the number of documents in the result

count = establishments.count_documents(query)
print('Number of documents with hygiene scores equal to 20: ', count)

# Display the first document in the results using pprint
pprint(establishments.find_one(query))
# Out:
# Number of documents with hygiene scores equal to 20:  95
# {'AddressLine1': '5-6 Southfields Road',
#  'AddressLine2': 'Eastbourne',
#  'AddressLine3': 'East Sussex',
#  'AddressLine4': '',
#  'BusinessName': 'The Chase Rest Home',
#  'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  'ChangesByServerID': 0,
#  'Distance': 4613.888288172291,
#  'FHRSID': 110681,
#  'LocalAuthorityBusinessID': '4029',
#  'LocalAuthorityCode': '102',
#  'LocalAuthorityEmailAddress': 'Customerfirst@eastbourne.gov.uk',
#  'LocalAuthorityName': 'Eastbourne',
#  'LocalAuthorityWebSite': 'http://www.eastbourne.gov.uk/foodratings',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'BN21 1BU',
#  'RatingDate': '2021-09-23T00:00:00',
#  'RatingKey': 'fhrs_0_en-gb',
#  'RatingValue': 0,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('66e35ea4ee7147f4805c88ae'),
#  'geocode': {'latitude': 50.769705, 'longitude': 0.27694},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/110681',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 20, 'Hygiene': 20, 'Structural': 20}}

# %%
#Convert the result to a Pandas DataFrame
results = list(establishments.find(query))
hygiene_df= pd.DataFrame(results)

# Export DataFrame to csv file
hygiene_df.to_csv("hygiene_df.csv", index=False)

# Display the number of rows in the DataFrame
print(f"Number of rows in DataFrame: {len(hygiene_df)}")

# Display the first 10 rows of the DataFrame
print(hygiene_df.head(10))
# Out:
# Number of rows in DataFrame: 95
#                         _id   FHRSID  ChangesByServerID  \
# 0  66e35ea4ee7147f4805c88ae   110681                  0
# 1  66e35ea4ee7147f4805c8c2b   612039                  0
# 2  66e35ea4ee7147f4805c8f37   730933                  0
# 3  66e35ea4ee7147f4805c9125   172735                  0
# 4  66e35ea4ee7147f4805c9adf   512854                  0
# 5  66e35ea4ee7147f4805cb221   155648                  0
# 6  66e35ea5ee7147f4805cbe74   644109                  0
# 7  66e35ea5ee7147f4805cc59b   972876                  0
# 8  66e35ea5ee7147f4805cce6a  1417416                  0
# 9  66e35ea5ee7147f4805cd474  1384371                  0
#
#   LocalAuthorityBusinessID                                       BusinessName  \
# 0                     4029                                The Chase Rest Home
# 1                1970/FOOD                                         Brenalwood
# 2                1698/FOOD                                      Melrose Hotel
# 3             PI/000023858                                      Seaford Pizza
# 4            12/00816/BUTH                                   Ashby's Butchers
# 5              EH/00006058                                      Golden Palace
# 6                    41811                                              F & S
# 7          17/00059/FOOD/S  Westview Playgroup Based At Downsview Comm Pri...
# 8              21/00350/CP                        Whatever The Weather Coffee
# 9           21/00062/MIXED                        Kings Restaurant (Oriental)
#
#                         BusinessType  BusinessTypeID  \
# 0                    Caring Premises               5
# 1                    Caring Premises               5
# 2  Hotel/bed & breakfast/guest house            7842
# 3             Takeaway/sandwich shop            7844
# 4                  Retailers - other            4613
# 5             Takeaway/sandwich shop            7844
# 6                  Retailers - other            4613
# 7            Other catering premises            7841
# 8                     Mobile caterer            7846
# 9             Takeaway/sandwich shop            7844
#
#                          AddressLine1        AddressLine2 AddressLine3  ...  \
# 0                5-6 Southfields Road          Eastbourne  East Sussex  ...
# 1                           Hall Lane  Walton-on-the-Naze        Essex  ...
# 2               53 Marine Parade East      Clacton On Sea        Essex  ...
# 3                       4 High Street             Seaford  East Sussex  ...
# 4                777 Southchurch Road     Southend-On-Sea        Essex  ...
# 5                       7 London Road            Rayleigh        Essex  ...
# 6                                          81 Southernhay     Basildon  ...
# 7  Downsview Community Primary School        Beech Avenue      Swanley  ...
# 8                           EMR Erith          Manor Road        Erith  ...
# 9                       43 Kings Road           Brentwood        Essex  ...
#
#                       LocalAuthorityWebSite  \
# 0  http://www.eastbourne.gov.uk/foodratings
# 1             http://www.tendringdc.gov.uk/
# 2             http://www.tendringdc.gov.uk/
# 3       http://www.lewes-eastbourne.gov.uk/
# 4                http://www.southend.gov.uk
# 5                http://www.rochford.gov.uk
# 6                http://www.basildon.gov.uk
# 7              http://www.sevenoaks.gov.uk/
# 8                  http://www.bexley.gov.uk
# 9              http://www.brentwood.gov.uk/
#
#               LocalAuthorityEmailAddress  \
# 0        Customerfirst@eastbourne.gov.uk
# 1             fhsadmin@tendringdc.gov.uk
# 2             fhsadmin@tendringdc.gov.uk
# 3    ehealth.ldc@lewes-eastbourne.gov.uk
# 4    EnvironmentalHealth@southend.gov.uk
# 5       customerservices@rochford.gov.uk
# 6                    ehs@basildon.gov.uk
# 7  environmental.health@sevenoaks.gov.uk
# 8              food.safety@bexley.gov.uk
# 9             envhealth@brentwood.gov.uk
#
#                                               scores  SchemeType  \
# 0  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...        FHRS
# 1  {'Hygiene': 20, 'Structural': 15, 'ConfidenceI...        FHRS
# 2  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...        FHRS
# 3  {'Hygiene': 20, 'Structural': 10, 'ConfidenceI...        FHRS
# 4  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...        FHRS
# 5  {'Hygiene': 20, 'Structural': 15, 'ConfidenceI...        FHRS
# 6  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...        FHRS
# 7  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...        FHRS
# 8  {'Hygiene': 20, 'Structural': 15, 'ConfidenceI...        FHRS
# 9  {'Hygiene': 20, 'Structural': 25, 'ConfidenceI...        FHRS
#
#                                              geocode RightToReply  \
# 0      {'longitude': 0.27694, 'latitude': 50.769705}
# 1     {'longitude': 1.278721, 'latitude': 51.857536}
# 2      {'longitude': 1.15927, 'latitude': 51.789429}
# 3      {'longitude': 0.10202, 'latitude': 50.770885}
# 4     {'longitude': 0.736349, 'latitude': 51.541448}
# 5     {'longitude': 0.602364, 'latitude': 51.591515}
# 6      {'longitude': 0.462307, 'latitude': 51.57005}
# 7   {'longitude': 0.1864034, 'latitude': 51.3954686}
# 8  {'longitude': 0.19265740017645, 'latitude': 51...
# 9       {'longitude': 0.2983, 'latitude': 51.618135}
#
#       Distance NewRatingPending  \
# 0  4613.888288            False
# 1  4617.965824            False
# 2  4619.656144            False
# 3  4620.421725            False
# 4  4625.565258            False
# 5  4632.276890            False
# 6  4636.552523            False
# 7  4640.152449            False
# 8  4642.935252            False
# 9  4644.277277            False
#
#                                                 meta  \
# 0  {'dataSource': None, 'extractDate': '0001-01-0...
# 1  {'dataSource': None, 'extractDate': '0001-01-0...
# 2  {'dataSource': None, 'extractDate': '0001-01-0...
# 3  {'dataSource': None, 'extractDate': '0001-01-0...
# 4  {'dataSource': None, 'extractDate': '0001-01-0...
# 5  {'dataSource': None, 'extractDate': '0001-01-0...
# 6  {'dataSource': None, 'extractDate': '0001-01-0...
# 7  {'dataSource': None, 'extractDate': '0001-01-0...
# 8  {'dataSource': None, 'extractDate': '0001-01-0...
# 9  {'dataSource': None, 'extractDate': '0001-01-0...
#
#                                                links
# 0  [{'rel': 'self', 'href': 'https://api.ratings....
# 1  [{'rel': 'self', 'href': 'https://api.ratings....
# 2  [{'rel': 'self', 'href': 'https://api.ratings....
# 3  [{'rel': 'self', 'href': 'https://api.ratings....
# 4  [{'rel': 'self', 'href': 'https://api.ratings....
# 5  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 6  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 7  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 8  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 9  [{'rel': 'self', 'href': 'http://api.ratings.f...
#
# [10 rows x 28 columns]

# %% [markdown]
# ### 2. Which establishments in London have a `RatingValue` greater than or equal to 4?

# %%
# Find the establishments with London as the Local Authority and has a RatingValue greater than or equal to 4.
query = {"LocalAuthorityName": {"$regex": "London"}, "RatingValue": {"$gte": 4}}

# Use count_documents to display the number of documents in the result
count = establishments.count_documents(query)
print(f"Number of establishments in London with RatingValue >= 4: {count}")

# Display the first document in the results using pprint
pprint(establishments.find_one(query))
# Out:
# Number of establishments in London with RatingValue >= 4: 87
# {'AddressLine1': 'Oak Apple Farm Building 103 Sheernes Docks',
#  'AddressLine2': 'Sheppy Kent',
#  'AddressLine3': '',
#  'AddressLine4': '',
#  'BusinessName': "Charlie's",
#  'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  'ChangesByServerID': 0,
#  'Distance': 4627.439467780196,
#  'FHRSID': 621707,
#  'LocalAuthorityBusinessID': 'PI/000025307',
#  'LocalAuthorityCode': '508',
#  'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk',
#  'LocalAuthorityName': 'City of London Corporation',
#  'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'ME12',
#  'RatingDate': '2021-10-18T00:00:00',
#  'RatingKey': 'fhrs_4_en-gb',
#  'RatingValue': 4,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('66e35ea4ee7147f4805ca2c4'),
#  'geocode': {'latitude': 51.369321, 'longitude': 0.508551},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/621707',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 5, 'Structural': 10}}

# %%
# Convert the result to a Pandas DataFrame
results = list(establishments.find(query))
data_df = pd.DataFrame(results)

# Display the number of rows in the DataFrame
print(f"Number of rows is: {len(data_df)}")

# Display the first 10 rows of the DataFrame
print(data_df.head(10))
# Out:
# Number of rows is: 222
#                         _id   FHRSID  ChangesByServerID  \
# 0  66e35ea5ee7147f4805ce0db   695223                  0
# 1  66e35ea5ee7147f4805ce0f0  1380578                  0
# 2  66e35ea5ee7147f4805ce10a   694609                  0
# 3  66e35ea5ee7147f4805ce120   695241                  0
# 4  66e35ea5ee7147f4805ce126   694478                  0
# 5  66e35ea5ee7147f4805ce12f   909912                  0
# 6  66e35ea5ee7147f4805ce146   695204                  0
# 7  66e35ea5ee7147f4805ce14b   694482                  0
# 8  66e35ea5ee7147f4805ce16b   940026                  0
# 9  66e35ea5ee7147f4805ce195   694606                  0
#
#   LocalAuthorityBusinessID                         BusinessName  \
# 0             PI/000178842                              Iceland
# 1                    14425  Howe and Co Fish and Chips - Van 17
# 2             PI/000116619                            Volunteer
# 3             PI/000179088              Plumstead Manor Nursery
# 4             PI/000086506                    Atlantic Fish Bar
# 5             PI/000201100      Lumbini Grocery Ltd T/A Al-Iman
# 6             PI/000177985                                Tesco
# 7             PI/000086551                               Greggs
# 8             PI/000177403                           Abbi Wines
# 9             PI/000116584                 Fineway Cash & Carry
#
#                             BusinessType  BusinessTypeID  \
# 0  Retailers - supermarkets/hypermarkets            7840
# 1                         Mobile caterer            7846
# 2                      Pub/bar/nightclub            7843
# 3                        Caring Premises               5
# 4                 Takeaway/sandwich shop            7844
# 5                      Retailers - other            4613
# 6  Retailers - supermarkets/hypermarkets            7840
# 7                 Takeaway/sandwich shop            7844
# 8                      Retailers - other            4613
# 9                      Retailers - other            4613
#
#                                         AddressLine1 AddressLine2  \
# 0                    144 - 146 Plumstead High Street
# 1  Restaurant And Premises 107A Plumstead High St...
# 2                    130 - 132 Plumstead High Street
# 3               Plumstead Manor School Old Mill Road
# 4                                   35 Lakedale Road
# 5                                   17 Lakedale Road
# 6                                   18 Lakedale Road
# 7                                    6 Lakedale Road
# 8                              12 - 14 Lakedale Road
# 9                          112 Plumstead High Street
#
#   AddressLine3  ...             LocalAuthorityWebSite  \
# 0    Plumstead  ...  http://www.royalgreenwich.gov.uk
# 1    Plumstead  ...  http://www.royalgreenwich.gov.uk
# 2    Plumstead  ...  http://www.royalgreenwich.gov.uk
# 3    Plumstead  ...  http://www.royalgreenwich.gov.uk
# 4    Plumstead  ...  http://www.royalgreenwich.gov.uk
# 5    Plumstead  ...  http://www.royalgreenwich.gov.uk
# 6    Plumstead  ...  http://www.royalgreenwich.gov.uk
# 7    Plumstead  ...  http://www.royalgreenwich.gov.uk
# 8    Plumstead  ...  http://www.royalgreenwich.gov.uk
# 9    Plumstead  ...  http://www.royalgreenwich.gov.uk
#
#      LocalAuthorityEmailAddress  \
# 0  health@royalgreenwich.gov.uk
# 1  health@royalgreenwich.gov.uk
# 2  health@royalgreenwich.gov.uk
# 3  health@royalgreenwich.gov.uk
# 4  health@royalgreenwich.gov.uk
# 5  health@royalgreenwich.gov.uk
# 6  health@royalgreenwich.gov.uk
# 7  health@royalgreenwich.gov.uk
# 8  health@royalgreenwich.gov.uk
# 9  health@royalgreenwich.gov.uk
#
#                                               scores  SchemeType  \
# 0  {'Hygiene': 0, 'Structural': 5, 'ConfidenceInM...        FHRS
# 1  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...        FHRS
# 2  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...        FHRS
# 3  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...        FHRS
# 4  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...        FHRS
# 5  {'Hygiene': 0, 'Structural': 5, 'ConfidenceInM...        FHRS
# 6  {'Hygiene': 0, 'Structural': 5, 'ConfidenceInM...        FHRS
# 7  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...        FHRS
# 8  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...        FHRS
# 9  {'Hygiene': 5, 'Structural': 5, 'ConfidenceInM...        FHRS
#
#                                              geocode RightToReply  \
# 0  {'longitude': 0.0924199968576431, 'latitude': ...
# 1  {'longitude': 0.0925370007753372, 'latitude': ...
# 2     {'longitude': 0.09208, 'latitude': 51.4873437}
# 3  {'longitude': 0.0859939977526665, 'latitude': ...
# 4   {'longitude': 0.0912164, 'latitude': 51.4867296}
# 5   {'longitude': 0.0916256, 'latitude': 51.4871632}
# 6  {'longitude': 0.0912820026278496, 'latitude': ...
# 7  {'longitude': 0.0912820026278496, 'latitude': ...
# 8   {'longitude': 0.0908895, 'latitude': 51.4871401}
# 9   {'longitude': 0.0909382, 'latitude': 51.4876089}
#
#       Distance NewRatingPending  \
# 0  4646.946071            False
# 1  4646.955931            False
# 2  4646.965635            False
# 3  4646.974010            False
# 4  4646.974612            False
# 5  4646.975587            False
# 6  4646.987290            False
# 7  4646.987290            False
# 8  4647.001583            False
# 9  4647.016995            False
#
#                                                 meta  \
# 0  {'dataSource': None, 'extractDate': '0001-01-0...
# 1  {'dataSource': None, 'extractDate': '0001-01-0...
# 2  {'dataSource': None, 'extractDate': '0001-01-0...
# 3  {'dataSource': None, 'extractDate': '0001-01-0...
# 4  {'dataSource': None, 'extractDate': '0001-01-0...
# 5  {'dataSource': None, 'extractDate': '0001-01-0...
# 6  {'dataSource': None, 'extractDate': '0001-01-0...
# 7  {'dataSource': None, 'extractDate': '0001-01-0...
# 8  {'dataSource': None, 'extractDate': '0001-01-0...
# 9  {'dataSource': None, 'extractDate': '0001-01-0...
#
#                                                links
# 0  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 1  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 2  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 3  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 4  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 5  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 6  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 7  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 8  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 9  [{'rel': 'self', 'href': 'http://api.ratings.f...
#
# [10 rows x 28 columns]

# %% [markdown]
# ### 3. What are the top 5 establishments with a `RatingValue` rating value of 5, sorted by lowest hygiene score, nearest to the new restaurant added, "Penang Flavours"?

# %%
# Search within 0.01 degree on either side of the latitude and longitude.
# Rating value must equal 5
# Sort by hygiene score

degree_search = 0.01
latitude = 51.49020000
longitude = 0.08400000

query = query = {
    "RatingValue": 5,
    "geocode.latitude": {
        "$gte": latitude - degree_search,
        "$lte": latitude + degree_search
    },
    "geocode.longitude": {
        "$gte": longitude - degree_search,
        "$lte": longitude + degree_search
    }
}
sort = [("scores.Hygiene", 1)]  
limit = 5

# Retrieve and print the results
results = list(establishments.find(query).sort(sort).limit(limit))

for result in results:
    pprint(result)
# Out:
# {'AddressLine1': '130 - 132 Plumstead High Street',
#  'AddressLine2': '',
#  'AddressLine3': 'Plumstead',
#  'AddressLine4': 'Greenwich',
#  'BusinessName': 'Volunteer',
#  'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  'ChangesByServerID': 0,
#  'Distance': 4646.965634598608,
#  'FHRSID': 694609,
#  'LocalAuthorityBusinessID': 'PI/000116619',
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'SE18 1JQ',
#  'RatingDate': '2019-08-05T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('66e35ea5ee7147f4805ce10a'),
#  'geocode': {'latitude': 51.4873437, 'longitude': 0.09208},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/694609',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 0}}
# {'AddressLine1': '35 Lakedale Road',
#  'AddressLine2': '',
#  'AddressLine3': 'Plumstead',
#  'AddressLine4': 'Greenwich',
#  'BusinessName': 'Atlantic Fish Bar',
#  'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  'ChangesByServerID': 0,
#  'Distance': 4646.974611855838,
#  'FHRSID': 694478,
#  'LocalAuthorityBusinessID': 'PI/000086506',
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'SE18 1PR',
#  'RatingDate': '2021-06-16T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('66e35ea5ee7147f4805ce126'),
#  'geocode': {'latitude': 51.4867296, 'longitude': 0.0912164},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/694478',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 0, 'Structural': 0}}
# {'AddressLine1': '144 - 146 Plumstead High Street',
#  'AddressLine2': '',
#  'AddressLine3': 'Plumstead',
#  'AddressLine4': 'Greenwich',
#  'BusinessName': 'Iceland',
#  'BusinessType': 'Retailers - supermarkets/hypermarkets',
#  'BusinessTypeID': 7840,
#  'ChangesByServerID': 0,
#  'Distance': 4646.946071297699,
#  'FHRSID': 695223,
#  'LocalAuthorityBusinessID': 'PI/000178842',
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'SE18 1JQ',
#  'RatingDate': '2019-11-13T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('66e35ea5ee7147f4805ce0db'),
#  'geocode': {'latitude': 51.4871482849121, 'longitude': 0.0924199968576431},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/695223',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 0, 'Structural': 5}}
# {'AddressLine1': 'Restaurant And Premises 107A Plumstead High Street',
#  'AddressLine2': '',
#  'AddressLine3': 'Plumstead',
#  'AddressLine4': 'Greenwich',
#  'BusinessName': 'Howe and Co Fish and Chips - Van 17',
#  'BusinessType': 'Mobile caterer',
#  'BusinessTypeID': 7846,
#  'ChangesByServerID': 0,
#  'Distance': 4646.95593107927,
#  'FHRSID': 1380578,
#  'LocalAuthorityBusinessID': '14425',
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'SE18 1SE',
#  'RatingDate': '2021-11-11T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('66e35ea5ee7147f4805ce0f0'),
#  'geocode': {'latitude': 51.4875335693359, 'longitude': 0.0925370007753372},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1380578',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 0}}
# {'AddressLine1': 'Plumstead Manor School Old Mill Road',
#  'AddressLine2': '',
#  'AddressLine3': 'Plumstead',
#  'AddressLine4': 'Greenwich',
#  'BusinessName': 'Plumstead Manor Nursery',
#  'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  'ChangesByServerID': 0,
#  'Distance': 4646.9740101340385,
#  'FHRSID': 695241,
#  'LocalAuthorityBusinessID': 'PI/000179088',
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'SE18 1QG',
#  'RatingDate': '2021-06-16T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('66e35ea5ee7147f4805ce120'),
#  'geocode': {'latitude': 51.481517791748, 'longitude': 0.0859939977526665},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/695241',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 0, 'Structural': 0}}

# %%
# Convert result to Pandas DataFrame
# Convert result to Pandas DataFrame
penang_df = pd.DataFrame(results)

# Export DataFrame to csv file
penang_df.to_csv("penang_df.csv", index=False, header=True)

penang_df
# Out:
#                         _id   FHRSID  ChangesByServerID  \
# 0  66e35ea5ee7147f4805ce10a   694609                  0
# 1  66e35ea5ee7147f4805ce126   694478                  0
# 2  66e35ea5ee7147f4805ce0db   695223                  0
# 3  66e35ea5ee7147f4805ce0f0  1380578                  0
# 4  66e35ea5ee7147f4805ce120   695241                  0
#
#   LocalAuthorityBusinessID                         BusinessName  \
# 0             PI/000116619                            Volunteer
# 1             PI/000086506                    Atlantic Fish Bar
# 2             PI/000178842                              Iceland
# 3                    14425  Howe and Co Fish and Chips - Van 17
# 4             PI/000179088              Plumstead Manor Nursery
#
#                             BusinessType  BusinessTypeID  \
# 0                      Pub/bar/nightclub            7843
# 1                 Takeaway/sandwich shop            7844
# 2  Retailers - supermarkets/hypermarkets            7840
# 3                         Mobile caterer            7846
# 4                        Caring Premises               5
#
#                                         AddressLine1 AddressLine2  \
# 0                    130 - 132 Plumstead High Street
# 1                                   35 Lakedale Road
# 2                    144 - 146 Plumstead High Street
# 3  Restaurant And Premises 107A Plumstead High St...
# 4               Plumstead Manor School Old Mill Road
#
#   AddressLine3  ...             LocalAuthorityWebSite  \
# 0    Plumstead  ...  http://www.royalgreenwich.gov.uk
# 1    Plumstead  ...  http://www.royalgreenwich.gov.uk
# 2    Plumstead  ...  http://www.royalgreenwich.gov.uk
# 3    Plumstead  ...  http://www.royalgreenwich.gov.uk
# 4    Plumstead  ...  http://www.royalgreenwich.gov.uk
#
#      LocalAuthorityEmailAddress  \
# 0  health@royalgreenwich.gov.uk
# 1  health@royalgreenwich.gov.uk
# 2  health@royalgreenwich.gov.uk
# 3  health@royalgreenwich.gov.uk
# 4  health@royalgreenwich.gov.uk
#
#                                               scores  SchemeType  \
# 0  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...        FHRS
# 1  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...        FHRS
# 2  {'Hygiene': 0, 'Structural': 5, 'ConfidenceInM...        FHRS
# 3  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...        FHRS
# 4  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...        FHRS
#
#                                              geocode RightToReply  \
# 0     {'longitude': 0.09208, 'latitude': 51.4873437}
# 1   {'longitude': 0.0912164, 'latitude': 51.4867296}
# 2  {'longitude': 0.0924199968576431, 'latitude': ...
# 3  {'longitude': 0.0925370007753372, 'latitude': ...
# 4  {'longitude': 0.0859939977526665, 'latitude': ...
#
#       Distance NewRatingPending  \
# 0  4646.965635            False
# 1  4646.974612            False
# 2  4646.946071            False
# 3  4646.955931            False
# 4  4646.974010            False
#
#                                                 meta  \
# 0  {'dataSource': None, 'extractDate': '0001-01-0...
# 1  {'dataSource': None, 'extractDate': '0001-01-0...
# 2  {'dataSource': None, 'extractDate': '0001-01-0...
# 3  {'dataSource': None, 'extractDate': '0001-01-0...
# 4  {'dataSource': None, 'extractDate': '0001-01-0...
#
#                                                links
# 0  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 1  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 2  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 3  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 4  [{'rel': 'self', 'href': 'http://api.ratings.f...
#
# [5 rows x 28 columns]

# %% [markdown]
# ### 4. How many establishments in each Local Authority area have a hygiene score of 0?

# %%
# Create a pipeline that:
# 1. Matches establishments with a hygiene score of 0
match = {'$match': {'scores.Hygiene': {'$eq': 0}}}
# 2. Groups the matches by Local Authority
group = {'$group': {'_id': '$LocalAuthorityName',
                'count': {'$sum': 1}}}
# 3. Sorts the matches from highest to lowest
sort = {'$sort': {'count': -1}}
# Print the number of documents in the result
pipeline = [match, group, sort]
num_doc = list(establishments.aggregate(pipeline))
# Print the first 10 results
# Print the first 10 results
pprint(num_doc[0:10])
# Out:
# [{'_id': 'Thanet', 'count': 2674},
#  {'_id': 'Greenwich', 'count': 2222},
#  {'_id': 'Newham', 'count': 1843},
#  {'_id': 'Medway', 'count': 1786},
#  {'_id': 'Maidstone', 'count': 1759},
#  {'_id': 'Swale', 'count': 1690},
#  {'_id': 'Chelmsford', 'count': 1638},
#  {'_id': 'Bexley', 'count': 1623},
#  {'_id': 'Southend-On-Sea', 'count': 1456},
#  {'_id': 'Tendring', 'count': 1402}]

# %%
# Convert the result to a Pandas DataFrame
result_df = pd.DataFrame(num_doc)
# Display the number of rows in the DataFrame
print("Rows in DataFrame: ", len(result_df))
# Display the first 10 rows of the DataFrame
result_df.head(10)
# Out:
# Rows in DataFrame:  55
#                _id  count
# 0           Thanet   2674
# 1        Greenwich   2222
# 2           Newham   1843
# 3           Medway   1786
# 4        Maidstone   1759
# 5            Swale   1690
# 6       Chelmsford   1638
# 7           Bexley   1623
# 8  Southend-On-Sea   1456
# 9         Tendring   1402
